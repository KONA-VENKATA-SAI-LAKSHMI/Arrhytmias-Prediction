# %%
import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib as plt



data=pd.read_csv("heart.csv")

features=data.loc[:,data.columns!='target'].values[:,1:]
labels=data.loc[:,'target'].values
scaler=MinMaxScaler((-1,1))
x=scaler.fit_transform(features)
y=labels


from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=10)
print(len(xtrain))
print(len(xtest))
print(len(ytrain))
print(len(ytest))

scores={}

# %%
import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib as plt



data=pd.read_csv("heart.csv")

features=data.loc[:,data.columns!='target'].values[:,1:]
labels=data.loc[:,'target'].values
scaler=MinMaxScaler((-1,1))
x=scaler.fit_transform(features)
y=labels


from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=10)
print(len(xtrain))
print(len(xtest))
print(len(ytrain))
print(len(ytest))

scores={}

# %%
scores={}
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
nb_model = GaussianNB()
nb_model.fit(xtrain, ytrain.ravel())
nb_predict_test = nb_model.predict(xtest)
print(nb_model)

from sklearn import metrics
print("Accuracy on training data: {0:.4f}".format(metrics.accuracy_score(ytest, nb_predict_test) * 100))
print("Precision on training data: {0:.4f}".format(metrics.precision_score(ytest, nb_predict_test) * 100))
print("Recall on training data: {0:.4f}".format(metrics.recall_score(ytest, nb_predict_test) * 100))
print("F1 score on training data: {0:.4f}".format(metrics.f1_score(ytest, nb_predict_test) * 100))
x=round((metrics.accuracy_score(ytest, nb_predict_test) * 100),2)
confusion_matrix(ytest, nb_predict_test)

yprediciton2 = nb_model.predict(xtest)
ytrue = ytest
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(ytrue, yprediciton2)

scores['NB']=x
print(scores)
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(CM, annot=True, linewidths=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.title("Naive Bayes Confusion_matrix")
plt.xlabel("Prediction(Ypred)")
plt.ylabel("Ytrue")
plt.show()
print("\n")

from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(ytest,yprediciton2)
roc_auc = auc(false_positive_rate, true_positive_rate)
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')

# %%
#Decision tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report 
rf = DecisionTreeClassifier(random_state=1)
rf.fit(xtrain, ytrain)
acc = rf.score(xtest, ytest) * 100
print("Decision Tree Algorithm Accuracy Score : {:.2f}%".format(acc))
scores["DT"] = round(acc,2)
yprediciton2 = rf.predict(xtest)
print("Precision on training data: {0:.2f}".format(metrics.precision_score(ytest, yprediciton2) * 100))
print("Recall on training data: {0:.2f}".format(metrics.recall_score(ytest, yprediciton2) * 100))
print("F1 score on training data: {0:.2f}".format(metrics.f1_score(ytest, yprediciton2) * 100))

ytrue = ytest
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(ytrue, yprediciton2)
rf_predict_test = rf.predict(xtest)
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(CM, annot=True, linewidths=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.title("Decision Tree Confusion Matrix")
plt.xlabel("Prediction(Ypred)")
plt.ylabel("Ytrue")
plt.show()
print(scores)


from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(ytest,rf_predict_test)
roc_auc = auc(false_positive_rate, true_positive_rate)
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
svm = SVC(gamma="auto")
svm.fit(xtrain, ytrain)
y_pred=svm.predict(xtest)
sv=accuracy_score(ytest,y_pred)*100
print("Test Accuracy of SVM Algorithm: {:.2f}%".format(sv)) 
scores["SVM"] = round(acc,2)
yprediciton2 = svm.predict(xtest)
print("Precision on training data: {0:.2f}".format(metrics.precision_score(ytest, yprediciton2) * 100))
print("Recall on training data: {0:.2f}".format(metrics.recall_score(ytest,yprediciton2 ) * 100))
print("F1 score on training data: {0:.2f}".format(metrics.f1_score(ytest,yprediciton2 ) * 100))
svm_test=svm.predict(xtest)
ytrue = ytest
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(ytrue, yprediciton2)

    
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(CM, annot=True, linewidths=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.title("SVM confusion matrix")
plt.xlabel("Prediction(Ypred)")
plt.ylabel("Ytrue")
plt.show()
print(scores)

from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(ytest,svm_test)
roc_auc = auc(false_positive_rate, true_positive_rate)
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier(n_estimators=10, random_state=40)
model.fit(xtrain, ytrain.ravel())
prediction_test = model.predict(xtest)
from sklearn import metrics
score_gb = metrics.accuracy_score(ytest, prediction_test)
p = (score_gb) * 100
print("Accuracy=", metrics.accuracy_score(ytest, prediction_test)*100)
scores["XGBOOST"] = round(p,2)
yprediciton2 = model.predict(xtest)
print("Precision on training data: {0:.2f}".format(metrics.precision_score(ytest, yprediciton2) * 100))
print("Recall on training data: {0:.2f}".format(metrics.recall_score(ytest,yprediciton2 ) * 100))
print("F1 score on training data: {0:.2f}".format(metrics.f1_score(ytest,yprediciton2 ) * 100))

ytrue = ytest
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(ytrue, yprediciton2)
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(CM, annot=True, linewidths=0.5, linecolor="yellow", fmt=".0f", ax=ax)
plt.title("XGBoost")
plt.xlabel("Prediction(Ypred)")
plt.ylabel("Ytrue")
plt.show()
print(scores)

from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(ytest,yprediciton2)
roc_auc = auc(false_positive_rate, true_positive_rate)
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10, random_state=40)
l=model.fit(xtrain, ytrain.ravel())
prediction_test = model.predict(xtest)
from sklearn import metrics
score_gb = metrics.accuracy_score(ytest, prediction_test)
p= round((score_gb) * 100,2)
print("Accuracy=", metrics.accuracy_score(ytest, prediction_test)*100)
yprediciton2=model.predict(xtest)
print("Precision on training data: {0:.2f}".format(metrics.precision_score(ytest, yprediciton2) * 100))
print("Recall on training data: {0:.2f}".format(metrics.recall_score(ytest,yprediciton2 ) * 100))
print("F1 score on training data: {0:.2f}".format(metrics.f1_score(ytest,yprediciton2 ) * 100))
ytrue = ytest
model_ens=model.predict(xtest)
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(ytrue, yprediciton2)
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(CM, annot=True, linewidths=0.5, linecolor="yellow", fmt=".0f", ax=ax)
plt.title("RandomForest")
plt.xlabel("Prediction(Ypred)")
plt.ylabel("Ytrue")
plt.show()
scores['RF']=p
print(scores)


from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(ytest,model_ens)
roc_auc = auc(false_positive_rate, true_positive_rate)
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')

# %%
from sklearn.ensemble import VotingClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
nb=GaussianNB()
LR = LogisticRegression()
svm=SVC(gamma='auto')
KNN =KNeighborsClassifier(n_neighbors = 42)
xg = XGBClassifier(random_state=42)
rf = RandomForestClassifier(random_state=42)

features=data.loc[:,data.columns!='target'].values[:,1:]
labels=data.loc[:,'target'].values
scaler=MinMaxScaler((-1,1))
x=scaler.fit_transform(features)
y=labels


from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=40)

vc = VotingClassifier(estimators = [('xgb',xg),('rf',rf),('log',LR),('svm',svm),('Knn',KNN),('nb',nb)], voting="hard")
vc.fit(xtrain,ytrain)

y_pred1 = vc.predict(xtest)
print("Precision on training data: {0:.2f}".format(metrics.precision_score(ytest, y_pred1) * 100))
print("Recall on training data: {0:.2f}".format(metrics.recall_score(ytest,y_pred1 ) * 100))
print("F1 score on training data: {0:.2f}".format(metrics.f1_score(ytest,y_pred1 ) * 100))
vot1 = metrics.accuracy_score(ytest, y_pred1)*100
print("Accuracy:",vot1)
scores['VOTING']=round(vot1,2)
yprediciton2=vc.predict(xtest)
vc_test=vc.predict(xtest)
    
ytrue = ytest
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(ytrue, yprediciton2)
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(CM, annot=True, linewidths=0.5, linecolor="yellow", fmt=".0f", ax=ax)
plt.title("Voting Alogorithm")
plt.xlabel("Prediction(Ypred)")
plt.ylabel("Ytrue")
plt.show()


from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(ytest,yprediciton2)
roc_auc = auc(false_positive_rate, true_positive_rate)
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')

print(scores)

# %%
import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib as plt

from tkinter import *
class DiseasePredictor:
    def __init__(self):
        self.window=Tk()
        self.window.geometry("800x400")
        self.window.title("DieseasePredictor")
        
        self.window.configure(bg="#c0ded9")
         
        
        self.age = Label(self.window ,text = "Age").grid(row = 0,column = 0)
        self.age_input = Entry(self.window,width=100)
        self.age_input.grid(row = 0,column = 1)
        
        self.sex = Label(self.window ,text = "Sex").grid(row = 1,column = 0)
        self.sex_input = Entry(self.window,width=100)
        self.sex_input.grid(row = 1,column = 1)
        
        self.chestpain = Label(self.window ,text = "Chest Pain").grid(row = 2,column = 0)
        self.chestpain_input = Entry(self.window,width=100)
        self.chestpain_input.grid(row = 2,column = 1)
        
        self.restingbloodpressure = Label(self.window ,text = "Resting Blood Pressure").grid(row = 3,column = 0)
        self.rbp_input = Entry(self.window,width=100)
        self.rbp_input.grid(row = 3,column = 1)
        
        self.serumcholestral = Label(self.window ,text = "Serum Cholestoral").grid(row = 4,column = 0)
        self.sc_input = Entry(self.window,width=100)
        self.sc_input.grid(row = 4,column = 1)
        
        self.fastingbloodpressure = Label(self.window ,text = "Fasting Blood Pressure").grid(row = 5,column = 0)
        self.fbp_input = Entry(self.window,width=100)
        self.fbp_input.grid(row = 5,column = 1)
        
        self.restingelectrocardiography = Label(self.window ,text = "Resting Electrocardiography").grid(row=6,column =0)
        self.rey_input = Entry(self.window,width=100)
        self.rey_input.grid(row = 6,column = 1)
        
        self.maximumheartrate  = Label(self.window ,text = "Maximum Heart Rate").grid(row = 7,column = 0)
        self.mhr_input = Entry(self.window,width=100)
        self.mhr_input.grid(row = 7,column = 1)
        
        self.exerciseinducedangina= Label(self.window ,text = "Exercise Induced Angina").grid(row = 8,column = 0)
        self.eie_input = Entry(self.window,width=100)
        self.eie_input.grid(row = 8,column = 1)
        
        self.oldpeak = Label(self.window ,text = "Oldpeak").grid(row = 9,column = 0)
        self.oldpeak_input = Entry(self.window,width=100)
        self.oldpeak_input.grid(row = 9,column = 1)
        
        self.slope = Label(self.window ,text = "Slope").grid(row = 10,column = 0)
        self.slope_input = Entry(self.window,width=100)
        self.slope_input.grid(row = 10,column = 1)
        
        self.ca = Label(self.window ,text = "Number of Vessels").grid(row = 11,column = 0)
        self.ca_input = Entry(self.window,width=100)
        self.ca_input.grid(row = 11,column = 1)
        
        self.thal = Label(self.window ,text = "Thal").grid(row = 12,column = 0)
        self.thal_input = Entry(self.window,width=100)
        self.thal_input.grid(row = 12,column = 1)
        
        self.predict=Button(self.window,text="Predict",command=self.get_inputs).grid(row=17,column=0)
        self.clear=Button(self.window,text="Clear",command=self.clear_inputs).grid(row=17,column=1)
        self.voting_classifier=Button(self.window,text="Result",command=self.voting_classifier).grid(row=17,column=2)
        
        
        
        data=pd.read_csv(r"C:\Users\Sai\Desktop\project\heart.csv")
        y=data.target.values
        x1=data.drop(["target"],axis=1)
        x = (x1 - np.min(x1))/(np.max(x1)-np.min(x1)).values
        
        
        from sklearn.model_selection import train_test_split
        self.xtrain,self.xtest,self.ytrain,self.ytest=train_test_split(x,y,test_size=0.3,random_state=40)


    def voting_classifier(self):
        from sklearn.ensemble import VotingClassifier
        from sklearn.ensemble import GradientBoostingClassifier
        from sklearn.ensemble import RandomForestClassifier
        from sklearn.svm import SVC
        from sklearn.neighbors import KNeighborsClassifier
        from sklearn.naive_bayes import GaussianNB
        from sklearn.linear_model import LogisticRegression
        nb=GaussianNB()
        LR = LogisticRegression()
        svm=SVC(gamma='auto')
        KNN =KNeighborsClassifier(n_neighbors = 42)
        xg = GradientBoostingClassifier(n_estimators=10, random_state=42)
        rf = RandomForestClassifier(random_state=42)
        vc = VotingClassifier(estimators = [('xgb',xg),('rf',rf),('log',LR),('svm',svm),('Knn',KNN),('nb',nb)], voting="hard")
        vc.fit(self.xtrain,self.ytrain)
        xtest=[[value for key,value in self.get_inputs().items()]]
        print(type(xtest))
        print(np.shape(xtest))
        output=vc.predict(xtest)
        
        #print(type(nb_predict_test))
        print(output)        
        if(output==0):
            x="Patient will not get the Disease"
            Label(self.window,text="Output " +x).grid(row=20,column=1)
        else:
            y="Patient will get the Disease"
            Label(self.window,text="Output " +y).grid(row=20,column=1)

            
        
 

    def clear_inputs(self):
        self.age_input.delete(0,'end')
        self.sex_input.delete(0,'end')
        self.chestpain_input.delete(0,'end')
        self.rbp_input.delete(0,'end')
        self.sc_input.delete(0,'end')
        self.fbp_input.delete(0,'end')
        self.rey_input.delete(0,'end')
        self.mhr_input.delete(0,'end')
        self.eie_input.delete(0,'end')
        self.oldpeak_input.delete(0,'end')
        self.slope_input.delete(0,'end')
        self.ca_input.delete(0,'end')
        self.thal_input.delete(0,'end')

        return
        
    def get_inputs(self):
        input_dict=dict()
        input_dict['age']=int(self.age_input.get())
        input_dict['sex']=int(self.sex_input.get())
        input_dict['cp']=int(self.chestpain_input.get())
        input_dict['threstbps']=int(self.rbp_input.get())
        input_dict['chol']=int(self.sc_input.get())
        input_dict['fbs']=int(self.fbp_input.get())
        input_dict['rey']=int(self.rey_input.get())
        input_dict['thalac']=int(self.mhr_input.get())
        input_dict['exang']=int(self.eie_input.get())
        input_dict['oldpeak']=float(self.oldpeak_input.get())
        input_dict['slope']=int(self.slope_input.get())
        input_dict['ca']=int(self.ca_input.get())
        input_dict['thal']=int(self.thal_input.get())
        print(input_dict)
    
        return input_dict
    


Predictor=DiseasePredictor()
Predictor.window.mainloop()
